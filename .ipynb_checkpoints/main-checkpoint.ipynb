# %%
from composer import (
    Agent,
    Vector,
    MCPClient,
    combine_tools,
    Thread,
    SystemMessage,
    HumanMessage,
    ThinkingEvent,
    ToolCallEvent,
    ToolResultEvent,
    AssistantEvent,
)
import subprocess

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
mcp = MCPClient(
    servers={
        "task_manager": {
            "transport": "http",
            "url": "http://127.0.0.1:8000/mcp",
            # optional:
            # "headers": {"Authorization": "Bearer ..."},
            # "timeout": 30,  # seconds (see langchain-mcp-adapters docs)
        }
    },
    tool_name_prefix=True,  # tools become task_manager_<name> if you add more servers
)

# %%
from langchain_core.tools import tool

@tool
def run_terminal_command(command: str) -> str:
    """Safely executes a shell command in a subprocess and returns stdout/stderr."""
    try:
        # Run command securely without shell=True to avoid injection issues
        result = subprocess.run(
            command.split(),
            capture_output=True,
            text=True,
            timeout=15
        )
        if result.returncode == 0:
            return f"Success:\n{result.stdout}"
        else:
            return f"Error (Exit Code {result.returncode}):\n{result.stderr}"
    except Exception as e:
        return f"Execution Failed: {str(e)}"

# %%
tools = await mcp.load_tools()

# %%
await mcp.load_resources()
blobs = await mcp.get_resource("taskmanager://agent-system-prompt")
task_manager_system_prompt = blobs[0].as_string()

# %%
model="openai/gpt-oss-120b:free"
emb_model="nvidia/llama-nemotron-embed-vl-1b-v2:free"

# %%
agent = Agent(
    model=model,
    base_url=os.getenv("BASE_URL"),
    api_key=os.getenv("API_KEY"),
    tools=[mcp, run_terminal_command],
    reasoning={"effort": "medium"},  # or reasoning=True
)

# %%
thread = Thread()

# %%
system = f"""
You are an ReAct and conversational agent. your goal is to perform and complete the user provided task.
- you will be having access to multiple MCP server tool which you can use to complete the user provided task and it's objective.
- on completion of the task always respond to user in well defined report.
- for conversational based query as per the query respond to used in well defined report or in general response.
- always mention the task id in final response report. 

---

{task_manager_system_prompt}
"""

# %%
SystemMessage(system) | thread
# Out:
# Thread(messages=1)

# %%
thread.append(HumanMessage("hi"))

# %%
(await (thread | agent)).content
# Out:
# '**Report**\n\nHi! 👋  \nI’m ready to help you with whatever you need—whether that’s answering a question, solving a problem, or carrying out a more involved task that may involve running commands or organizing work steps.\n\nJust let me know what you’d like to accomplish, and I’ll set up a structured task (plan, checklist, notes, and final report) to keep everything organized and ensure a clear, verifiable outcome.'

# %%
HumanMessage("I want you to tell me the system info, as much you can tell me about my system, and user") | thread
# Out:
# Thread(messages=4)

# %%
# HumanMessage("why this many tool calls and adding rough so late and todos as well?") | thread
# Out:
# Thread(messages=84)

# %%
async for event in agent.astream_events(thread):
    if isinstance(event, ThinkingEvent):
        print("[think]", event.text, end="")
    elif isinstance(event, ToolCallEvent):
        # print("[tool]", event.call.name, event.call.args)  # args is dict, not JSON string
        print("[tool]", event.call.name)
    # elif isinstance(event, ToolResultEvent):
    #     print("[result]", event.result.content)
    elif isinstance(event, AssistantEvent):
        print(event.text, end="")
# Out:
# [tool] task_manager_create_task
# [tool] task_manager_set_plan
# [tool] task_manager_add_todos
# [tool] run_terminal_command
# [tool] run_terminal_command
# [tool] task_manager_rough_list
# [tool] run_terminal_command
# [tool] task_manager_rough_add
# [tool] task_manager_get_todos
# [tool] run_terminal_command
# [tool] task_manager_toggle_todo
# [tool] run_terminal_command
# [tool] task_manager_rough_get
# [tool] run_terminal_command
# [tool] run_terminal_command
# [tool] run_terminal_command
# [tool] task_manager_rough_update
# [tool] run_terminal_command
# [tool] run_terminal_command
# [tool] run_terminal_command
# [tool] run_terminal_command
# [tool] run_terminal_command
# [tool] run_terminal_command
# [tool] run_terminal_command
# [tool] run_terminal_command
# [tool] run_terminal_command
# [tool] task_manager_toggle_todo
# [tool] run_terminal_command
# [tool] run_terminal_command
# [tool] run_terminal_command
# langchain_openai.stream_chunk_timeout fired
# ------------------------------------------------
# CancelledError Traceback (most recent call last)
# File C:\Python314\Lib\asyncio\tasks.py:488, in wait_for(fut, timeout)
#     487 async with timeouts.timeout(timeout):
# --> 488     return await fut
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\openai\_streaming.py:158, in AsyncStream.__aiter__(self)
#     157 async def __aiter__(self) -> AsyncIterator[_T]:
# --> 158     async for item in self._iterator:
#     159         yield item
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\openai\_streaming.py:172, in AsyncStream.__stream__(self)
#     171 try:
# --> 172     async for sse in iterator:
#     173         if sse.data.startswith("[DONE]"):
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\openai\_streaming.py:162, in AsyncStream._iter_events(self)
#     161 async def _iter_events(self) -> AsyncIterator[ServerSentEvent]:
# --> 162     async for sse in self._decoder.aiter_bytes(self.response.aiter_bytes()):
#     163         yield sse
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\openai\_streaming.py:319, in SSEDecoder.aiter_bytes(self, iterator)
#     318 """Given an iterator that yields raw binary data, iterate over it & yield every event encountered"""
# --> 319 async for chunk in self._aiter_chunks(iterator):
#     320     # Split before decoding so splitlines() only uses \r and \n
#     321     for raw_line in chunk.splitlines():
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\openai\_streaming.py:330, in SSEDecoder._aiter_chunks(self, iterator)
#     329 data = b""
# --> 330 async for chunk in iterator:
#     331     for line in chunk.splitlines(keepends=True):
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\httpx\_models.py:997, in Response.aiter_bytes(self, chunk_size)
#     996 with request_context(request=self._request):
# --> 997     async for raw_bytes in self.aiter_raw():
#     998         decoded = decoder.decode(raw_bytes)
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\httpx\_models.py:1055, in Response.aiter_raw(self, chunk_size)
#    1054 with request_context(request=self._request):
# -> 1055     async for raw_stream_bytes in self.stream:
#    1056         self._num_bytes_downloaded += len(raw_stream_bytes)
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\httpx\_client.py:176, in BoundAsyncStream.__aiter__(self)
#     175 async def __aiter__(self) -> typing.AsyncIterator[bytes]:
# --> 176     async for chunk in self._stream:
#     177         yield chunk
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\httpx\_transports\default.py:271, in AsyncResponseStream.__aiter__(self)
#     270 with map_httpcore_exceptions():
# --> 271     async for part in self._httpcore_stream:
#     272         yield part
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\httpcore\_async\connection_pool.py:407, in PoolByteStream.__aiter__(self)
#     406 await self.aclose()
# --> 407 raise exc from None
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\httpcore\_async\connection_pool.py:403, in PoolByteStream.__aiter__(self)
#     402 try:
# --> 403     async for part in self._stream:
#     404         yield part
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\httpcore\_async\http11.py:342, in HTTP11ConnectionByteStream.__aiter__(self)
#     341     await self.aclose()
# --> 342 raise exc
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\httpcore\_async\http11.py:334, in HTTP11ConnectionByteStream.__aiter__(self)
#     333 async with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334     async for chunk in self._connection._receive_response_body(**kwargs):
#     335         yield chunk
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\httpcore\_async\http11.py:203, in AsyncHTTP11Connection._receive_response_body(self, request)
#     202 while True:
# --> 203     event = await self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\httpcore\_async\http11.py:217, in AsyncHTTP11Connection._receive_event(self, timeout)
#     216 if event is h11.NEED_DATA:
# --> 217     data = await self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\httpcore\_backends\anyio.py:35, in AnyIOStream.read(self, max_bytes, timeout)
#      34 try:
# ---> 35     return await self._stream.receive(max_bytes=max_bytes)
#      36 except anyio.EndOfStream:  # pragma: nocover
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\anyio\streams\tls.py:239, in TLSStream.receive(self, max_bytes)
#     238 async def receive(self, max_bytes: int = 65536) -> bytes:
# --> 239     data = await self._call_sslobject_method(self._ssl_object.read, max_bytes)
#     240     if not data:
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\anyio\streams\tls.py:182, in TLSStream._call_sslobject_method(self, func, *args)
#     180         await self.transport_stream.send(self._write_bio.read())
# --> 182     data = await self.transport_stream.receive()
#     183 except EndOfStream:
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:1284, in SocketStream.receive(self, max_bytes)
#    1283 self._transport.resume_reading()
# -> 1284 await self._protocol.read_event.wait()
#    1285 self._transport.pause_reading()
#
# File C:\Python314\Lib\asyncio\locks.py:213, in Event.wait(self)
#     212 try:
# --> 213     await fut
#     214     return True
#
# CancelledError:
#
# The above exception was the direct cause of the following exception:
#
# TimeoutError   Traceback (most recent call last)
# File D:\app\backend\paneer\.venv\Lib\site-packages\langchain_openai\chat_models\_client_utils.py:652, in _astream_with_chunk_timeout(source, timeout, model_name)
#     651 try:
# --> 652     chunk = await asyncio.wait_for(it.__anext__(), timeout=timeout)
#     653 except StopAsyncIteration:
#
# File C:\Python314\Lib\asyncio\tasks.py:487, in wait_for(fut, timeout)
#     485         raise TimeoutError from exc
# --> 487 async with timeouts.timeout(timeout):
#     488     return await fut
#
# File C:\Python314\Lib\asyncio\timeouts.py:114, in Timeout.__aexit__(self, exc_type, exc_val, exc_tb)
#     113 if issubclass(exc_type, exceptions.CancelledError):
# --> 114     raise TimeoutError from exc_val
#     115 elif exc_val is not None:
#
# TimeoutError:
#
# The above exception was the direct cause of the following exception:
#
# StreamChunkTimeoutErrorTraceback (most recent call last)
# Cell In[22], line 1
# ----> 1 async for event in agent.astream_events(thread):
#       2     if isinstance(event, ThinkingEvent):
#       3         print("[think]", event.text, end="")
#       4     elif isinstance(event, ToolCallEvent):
#
# File D:\app\backend\paneer\composer\agent.py:851, in Agent.astream_events(self, thread, append_to, tools, auto_tool_call)
#     848 processor = StreamEventProcessor(input_message_count=len(input_messages))
#     850 try:
# --> 851     async for chunk in agent.astream(
#     852         {"messages": input_messages},
#     853         stream_mode=internal_mode,
#     854     ):
#     855         (
#     856             accumulated,
#     857             last_ai_message,
#    (...)    868             last_output_messages=last_output_messages,
#     869         )
#     870         for event in self._yield_events_from_chunk(chunk, processor):
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langgraph\pregel\main.py:3407, in Pregel.astream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    3405 for task in await loop.amatch_cached_writes():
#    3406     loop.output_writes(task.id, task.writes, cached=True)
# -> 3407 async for _ in runner.atick(
#    3408     [t for t in loop.tasks.values() if not t.writes],
#    3409     timeout=self.step_timeout,
#    3410     get_waiter=get_waiter,
#    3411     schedule_task=loop.aaccept_push,
#    3412 ):
#    3413     # emit output
#    3414     for o in _output(
#    3415         stream_mode,
#    3416         print_mode,
#    (...)   3422         _state_mapper,
#    3423     ):
#    3424         yield o
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langgraph\pregel\_runner.py:557, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     555 # panic on failure or timeout
#     556 try:
# --> 557     _panic_or_proceed(
#     558         futures.done.union(f for f, t in futures.items() if t is not None),
#     559         timeout_exc_cls=asyncio.TimeoutError,
#     560         panic=reraise,
#     561         handled_exception_ids=self._handled_exception_ids,
#     562         handled_futures=handled_futures,
#     563     )
#     564 except Exception as exc:
#     565     if tb := exc.__traceback__:
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langgraph\pregel\_runner.py:687, in _panic_or_proceed(futs, timeout_exc_cls, panic, handled_exception_ids, handled_futures)
#     685                 interrupts.append(exc)
#     686             elif fut not in SKIP_RERAISE_SET:
# --> 687                 raise exc
#     688 # raise combined interrupts
#     689 if interrupts:
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langgraph\pregel\_retry.py:706, in arun_with_retry(task, retry_policy, stream, match_cached_writes, configurable)
#     704             pass
#     705         break
# --> 706     return await task.proc.ainvoke(task.input, config)
#     707 result = await _arun_with_timeout(
#     708     task, config, resolved_timeout, attempt_ctx, stream=stream
#     709 )
#     710 _finish_timed_attempt(config, attempt_ctx)
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:733, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     731     # run in context
#     732     with set_config_context(config, run) as context:
# --> 733         input = await asyncio.create_task(
#     734             step.ainvoke(input, config, **kwargs), context=context
#     735         )
#     736 else:
#     737     input = await step.ainvoke(input, config, **kwargs)
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:501, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     499         await run_manager.on_chain_end(ret)
#     500 else:
# --> 501     ret = await self.afunc(*args, **kwargs)
#     502 if self.recurse and isinstance(ret, Runnable):
#     503     return await ret.ainvoke(input, config)
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langchain\agents\factory.py:1380, in create_agent.<locals>.amodel_node(state, runtime)
#    1368 request = ModelRequest(
#    1369     model=model,
#    1370     tools=default_tools,
#    (...)   1376     runtime=runtime,
#    1377 )
#    1379 if awrap_model_call_handler is None:
# -> 1380     model_response = await _execute_model_async(request)
#    1381     return _build_commands(model_response)
#    1383 result = await awrap_model_call_handler(request, _execute_model_async)
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langchain\agents\factory.py:1352, in create_agent.<locals>._execute_model_async(request)
#    1349 if request.system_message:
#    1350     messages = [request.system_message, *messages]
# -> 1352 output = await model_.ainvoke(messages)
#    1353 if name:
#    1354     output.name = name
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langchain_core\runnables\base.py:5894, in RunnableBindingBase.ainvoke(self, input, config, **kwargs)
#    5887 @override
#    5888 async def ainvoke(
#    5889     self,
#    (...)   5892     **kwargs: Any | None,
#    5893 ) -> Output:
# -> 5894     return await self.bound.ainvoke(
#    5895         input,
#    5896         self._merge_configs(config),
#    5897         **{**self.kwargs, **kwargs},
#    5898     )
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:497, in BaseChatModel.ainvoke(self, input, config, stop, **kwargs)
#     487 @override
#     488 async def ainvoke(
#     489     self,
#    (...)    494     **kwargs: Any,
#     495 ) -> AIMessage:
#     496     config = ensure_config(config)
# --> 497     llm_result = await self.agenerate_prompt(
#     498         [self._convert_input(input)],
#     499         stop=stop,
#     500         callbacks=config.get("callbacks"),
#     501         tags=config.get("tags"),
#     502         metadata=config.get("metadata"),
#     503         run_name=config.get("run_name"),
#     504         run_id=config.pop("run_id", None),
#     505         **kwargs,
#     506     )
#     507     return cast(
#     508         "AIMessage", cast("ChatGeneration", llm_result.generations[0][0]).message
#     509     )
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1834, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1825 @override
#    1826 async def agenerate_prompt(
#    1827     self,
#    (...)   1831     **kwargs: Any,
#    1832 ) -> LLMResult:
#    1833     prompt_messages = [p.to_messages() for p in prompts]
# -> 1834     return await self.agenerate(
#    1835         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#    1836     )
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1792, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1779     if run_managers:
#    1780         await asyncio.gather(
#    1781             *[
#    1782                 run_manager.on_llm_end(
#    (...)   1790             ]
#    1791         )
# -> 1792     raise exceptions[0]
#    1793 flattened_outputs = [
#    1794     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[union-attr]
#    1795     for res in results
#    1796 ]
#    1797 llm_output = self._combine_llm_outputs([res.llm_output for res in results])  # type: ignore[union-attr]
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:2084, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2082 index = -1
#    2083 index_type = ""
# -> 2084 async for chunk in self._astream(messages, stop=stop, **kwargs):
#    2085     chunk.message.response_metadata = _gen_info_and_msg_metadata(chunk)
#    2086     if self.output_version == "v1":
#    2087         # Overwrite .content with .content_blocks
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:3361, in ChatOpenAI._astream(self, *args, **kwargs)
#    3359         yield chunk
#    3360 else:
# -> 3361     async for chunk in super()._astream(*args, **kwargs):
#    3362         yield chunk
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1838, in BaseChatOpenAI._astream(self, messages, stop, run_manager, stream_usage, **kwargs)
#    1836 async with context_manager as response:
#    1837     is_first_chunk = True
# -> 1838     async for chunk in _astream_with_chunk_timeout(
#    1839         response,
#    1840         self.stream_chunk_timeout,
#    1841         model_name=self.model_name,
#    1842     ):
#    1843         if not isinstance(chunk, dict):
#    1844             chunk = chunk.model_dump()
#
# File D:\app\backend\paneer\.venv\Lib\site-packages\langchain_openai\chat_models\_client_utils.py:665, in _astream_with_chunk_timeout(source, timeout, model_name)
#     655 except asyncio.TimeoutError as e:
#     656     logger.warning(
#     657         "langchain_openai.stream_chunk_timeout fired",
#     658         extra={
#    (...)    663         },
#     664     )
# --> 665     raise StreamChunkTimeoutError(
#     666         timeout,
#     667         model_name=model_name,
#     668         chunks_received=chunks_received,
#     669     ) from e
#     670 chunks_received += 1
#     671 yield chunk
#
# StreamChunkTimeoutError: No streaming chunk received for 120.0s (model=openai/gpt-oss-120b:free, chunks_received=514). The connection may be alive at the TCP layer but is not producing content. Tune or disable via the `stream_chunk_timeout` constructor kwarg (set to None or 0 to disable) or the `LANGCHAIN_OPENAI_STREAM_CHUNK_TIMEOUT_S` env var. See also `http_socket_options` for the kernel-level TCP timeout that catches dead TCP peers.
# During task with name 'model' and id 'afdfa65f-af35-bdf9-c530-de8de13f436d'

# %%
v = Vector(
    model=emb_model,
    base_url=os.getenv("BASE_URL"),
    api_key=os.getenv("API_KEY"),
)

# %%
e = v.vector("hii")
