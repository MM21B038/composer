# %%
from composer import (
    Agent,
    Vector,
    MCPClient,
    combine_tools,
    Thread,
    SystemMessage,
    HumanMessage,
    ImageMessage,
    ThinkingEvent,
    ToolCallEvent,
    ToolResultEvent,
    AssistantEvent,
)
# from langchain_openrouter import ChatOpenRouter
from langchain_openai import ChatOpenAI
from pathlib import Path

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model="DeepSeek"
emb_model="Qwen3-Embedding-8B"
vision="VisionChat"

# %%
llm = ChatOpenAI(
    model=vision,
    base_url=os.getenv("BASE_URL"),
    api_key=os.getenv("API_KEY"),
    # reasoning={"effort": "medium"}
)

agent = Agent(
    model=llm,
)

# %%
thread = Thread()

# %%
HumanMessage("hii") | thread
# Out:
# Thread(messages=1)

# %%
thread | agent
# Out:
# AIMessage(content='\n\nHi there! 👋 How can I help you today? 😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 266, 'prompt_tokens': 12, 'total_tokens': 278, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'VisionChat', 'system_fingerprint': None, 'id': 'chatcmpl-927f5badc05a0e45', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ea70c-ee64-75f3-820e-4b3a4f6ee38b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 266, 'total_tokens': 278, 'input_token_details': {}, 'output_token_details': {}})

# %%
thread
# Out:
# Thread(messages=2)

# %%
path = Path().cwd() / "test_image.jpg"

# %%
HumanMessage("provide the value of the captcha image that I have attached").attach(path) | thread
# Out:
# Thread(messages=3)

# %%
thread | agent
# Out:
# AIMessage(content='\n\nThe value of the captcha image is **GphJ**.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 210, 'prompt_tokens': 102, 'total_tokens': 312, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'VisionChat', 'system_fingerprint': None, 'id': 'chatcmpl-877e6f201257c159', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ea6b5-34f3-71d1-928a-e7fd33b685dd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 102, 'output_tokens': 210, 'total_tokens': 312, 'input_token_details': {}, 'output_token_details': {}})
